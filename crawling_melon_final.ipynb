# %%
from IPython.display import Image
import numpy as np
import pandas as pd

# %%
genre1 = pd.read_csv('music_info1.csv')
print(genre1.shape)
genre1.head()
# Out:
# (1986, 5)
#    Unnamed: 0            title   artist  \
# 0           0        내 번호를 지워줘      박수진
# 1           1       빛 바래 사라지지만       마린
# 2           2  설월화 (Vocal 이서한)       그네
# 3           3              작은별  아웃오브캠퍼스
# 4           4              미안해      SOI
#
#                                                lyric      genre
# 0  이제는 사랑 같은 거 다시는 안 할 거라며 헤어지던 날 다짐했었는데 마음처럼 쉽지 ...        발라드
# 1  언젠가 함께 살자고 그저 바라보며 살면 된다고 몸 뉘일 작은방 한 칸과 그대만 있으...  발라드, 인디음악
# 2  사시사철 좋은 풍경을 바라보며 해를 보냈죠 많은 걸 놓고 적은 걸 얻은 그런 해를 ...  발라드, 인디음악
# 3  너는 참 특별한 작은 별 작지만 선명하게 꼭 필요한 곳을 비추지 너는 참 용감한 작...  발라드, 인디음악
# 4  미안해 내가 날 많이 아껴준 너인데 후회하겠지만 이제는 말할게 미안해 정말 미안해 ...  발라드, 인디음악

# %%
genre2 = pd.read_csv('music_info2.csv')

# %%
genre3 = pd.read_csv('music_info3.csv')

# %%
genre = pd.concat([genre1, genre2, genre3], ignore_index=True)
genre
# Out:
#       Unnamed: 0                            title     artist  \
# 0              0                        내 번호를 지워줘        박수진
# 1              1                       빛 바래 사라지지만         마린
# 2              2                  설월화 (Vocal 이서한)         그네
# 3              3                              작은별    아웃오브캠퍼스
# 4              4                              미안해        SOI
# ...          ...                              ...        ...
# 5663        1720  Let's get it on (prod. TWO TUK)      ziika
# 5664        1721                  내가 널 제일 행복하게 할게     리코틴에이션
# 5665        1722         Free my D (feat.45smoke)  DB hazard
# 5666        1723                 골프의 신 (SERI PAK)        희수킹
# 5667        1724         갤러리아 Remix (Feat. BPOLA)   XIO (시오)
#
#                                                   lyric       genre
# 0     이제는 사랑 같은 거 다시는 안 할 거라며 헤어지던 날 다짐했었는데 마음처럼 쉽지 ...         발라드
# 1     언젠가 함께 살자고 그저 바라보며 살면 된다고 몸 뉘일 작은방 한 칸과 그대만 있으...   발라드, 인디음악
# ...

# %%
genre.to_csv("music_genre.csv",  encoding='utf-8-sig')
